# %% [markdown]
# <a href="https://colab.research.google.com/github/Tuyet-nhi-le-ho/AIO-Exercise/blob/feature%2FM02EX01/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB
# To: /content/dog.jpeg
# 100% 33.7k/33.7k [00:00<00:00, 19.1MB/s]

# %%
import matplotlib.image as mpimg
import numpy as np


# Question 12, 13, 14
#

def to_gray(vector, method):
    h, w, _ = img.shape
    gray_img = np.ones((h, w))
    for height in range(h):
        for width in range(w):
            R, G, B = img[height][width]
            if method == "Lightness":
                gray_img[height][width] = (max(R, G, B) + min(R, G, B)) / 2
            elif method == "Average":
                gray_img[height][width] = sum([R, G, B]) / 3
            elif method == "Luminosity":
                gray_img[height][width] = 0.21 * R + 0.72 * G + 0.07 * B
    return gray_img


img = mpimg.imread("/content/dog.jpeg")
gray_img_01 = to_gray(img, method="Lightness")
print( gray_img_01[0, 0], sep="\n")
gray_img_02 = to_gray(img, method="Average")
print( gray_img_02[0][0], sep="\n")
gray_img_03 = to_gray(img, method="Luminosity")
print( gray_img_03[0][0], sep="\n")
# Out:
# <ipython-input-3-4ee646697631>:15: RuntimeWarning: overflow encountered in scalar add
#   gray_img[height][width] = (max(R, G, B) + min(R, G, B)) / 2
# 102.5
# 107.66666666666667
# 126.22999999999999
